# %% [markdown]
# <a href="https://colab.research.google.com/github/EZZERBOUTIABDELHAK/ML-plants/blob/main/model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("andresmgs/plantdec")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 74.1M/74.1M [00:04<00:00, 15.8MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/andresmgs/plantdec/versions/7

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo26n.pt")

model.train(data="/root/.cache/kagglehub/datasets/andresmgs/plantdec/versions/7/data.yaml",epochs=100)
# Out:
# ...
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model.save('yolocustom.pt')
